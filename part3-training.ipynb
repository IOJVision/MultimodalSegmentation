# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps
import nilearn as nl
import nibabel as nib

# ml libs
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard




np.set_printoptions(precision=3, suppress=True)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
"""
Label definition and required parameters
"""
SEGMENT_CLASSES = {
0 : 'No Tumor',
1 : 'Necrotic/Nuclear', #Tumor Nucleus
2 : 'Edema',#Edema Part
3 : 'Expanding Tumor' #Expanding Tumor Part
}

IMG_SIZE=128


VOLUME_SLICES = 100
VOLUME_START_AT = 22

# %%
# Verilerin ön incelenmesi ve görselleştirilmesi
TRAIN_DATASET_PATH = '/kaggle/input/bratsparts/Part3_Training'
VALIDATION_DATASET_PATH = '/kaggle/input/brats20-dataset-training-validation/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData'

# %%
"""Bu kod, böbrek ve beyin tümörlerinin segmentasyonu için Dice katsayısı, doğruluk, duyarlılık ve özgüllük gibi değerlerin hesaplanmasını sağlar.
dice_coef fonksiyonu, verilen gerçek ve tahmini etiketler arasında Dice katsayısını hesaplar ve döndürür. 
dice_coef_necrotic, dice_coef_edema ve dice_coef_enhancing fonksiyonları ise sırasıyla nekrotik, ödemli ve genişleyen tümör bölgeleri için 
Dice katsayısını hesaplar.precision fonksiyonu, verilen gerçek ve tahmini etiketler arasında doğruluk değerini hesaplar ve döndürür.
sensitivity fonksiyonu, verilen gerçek etiketler ve tahmini etiketler arasında duyarlılık değerini hesaplar ve döndürür.
specificity fonksiyonu ise verilen gerçek etiketler ve tahmini etiketler arasında özgüllük değerini hesaplar ve döndürür."""

def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
  
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss


def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,1])) + K.sum(K.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,2])) + K.sum(K.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,3])) + K.sum(K.square(y_pred[:,:,:,3])) + epsilon)



def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision


def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
import os
os.listdir(TRAIN_DATASET_PATH)
os.listdir(VALIDATION_DATASET_PATH)
# Out:
# ['BraTS20_Validation_084',
#  'BraTS20_Validation_118',
#  'BraTS20_Validation_111',
#  'BraTS20_Validation_060',
#  'BraTS20_Validation_034',
#  'BraTS20_Validation_045',
#  'BraTS20_Validation_027',
#  'BraTS20_Validation_073',
#  'BraTS20_Validation_014',
#  'BraTS20_Validation_047',
#  'BraTS20_Validation_096',
#  'BraTS20_Validation_068',
#  'BraTS20_Validation_090',
#  'BraTS20_Validation_038',
#  'BraTS20_Validation_017',
#  'BraTS20_Validation_069',
#  'BraTS20_Validation_071',
#  'BraTS20_Validation_092',
#  'BraTS20_Validation_015',
#  'BraTS20_Validation_117',
#  'BraTS20_Validation_004',
#  'BraTS20_Validation_103',
#  'BraTS20_Validation_035',
#  'BraTS20_Validation_033',
#  'BraTS20_Validation_021',
#  'BraTS20_Validation_061',
#  'BraTS20_Validation_079',
#  'BraTS20_Validation_085',
#  'BraTS20_Validation_112',
#  'BraTS20_Validation_065',
#  'BraTS20_Validation_037',
#  'BraTS20_Validation_053',
#  'BraTS20_Validation_005',
#  'BraTS20_Validation_064',
#  'BraTS20_Validation_091',
#  'BraTS20_Validation_042',
#  'BraTS20_Validation_078',
#  'BraTS20_Validation_100',
#  'BraTS20_Validation_019',
#  'BraTS20_Validation_063',
#  'BraTS20_Validation_010',
#  'BraTS20_Validation_081',
#  'BraTS20_Validation_022',
#  'BraTS20_Validation_043',
#  'BraTS20_Validation_074',
#  'BraTS20_Validation_072',
#  'BraTS20_Validation_094',
#  'BraTS20_Validation_076',
#  'BraTS20_Validation_095',
#  'BraTS20_Validation_018',
#  'BraTS20_Validation_056',
#  'BraTS20_Validation_105',
#  'BraTS20_Validation_121',
#  'BraTS20_Validation_089',
#  'BraTS20_Validation_115',
#  'BraTS20_Validation_082',
#  'BraTS20_Validation_011',
#  'BraTS20_Validation_124',
#  'BraTS20_Validation_098',
#  'BraTS20_Validation_108',
#  'BraTS20_Validation_110',
#  'BraTS20_Validation_116',
#  'BraTS20_Validation_036',
#  'BraTS20_Validation_044',
#  'BraTS20_Validation_097',
#  'BraTS20_Validation_102',
#  'BraTS20_Validation_008',
#  'BraTS20_Validation_040',
#  'BraTS20_Validation_003',
#  'BraTS20_Validation_058',
#  'BraTS20_Validation_119',
#  'BraTS20_Validation_051',
#  'BraTS20_Validation_006',
#  'name_mapping_validation_data.csv',
#  'BraTS20_Validation_106',
#  'BraTS20_Validation_031',
#  'BraTS20_Validation_020',
#  'BraTS20_Validation_046',
#  'BraTS20_Validation_054',
#  'BraTS20_Validation_050',
#  'BraTS20_Validation_101',
#  'BraTS20_Validation_109',
#  'BraTS20_Validation_055',
#  'BraTS20_Validation_070',
#  'BraTS20_Validation_062',
#  'BraTS20_Validation_028',
#  'BraTS20_Validation_066',
#  'BraTS20_Validation_049',
#  'BraTS20_Validation_012',
#  'BraTS20_Validation_016',
#  'BraTS20_Validation_025',
#  'BraTS20_Validation_059',
#  'BraTS20_Validation_057',
#  'BraTS20_Validation_002',
#  'BraTS20_Validation_026',
#  'BraTS20_Validation_007',
#  'BraTS20_Validation_030',
#  'BraTS20_Validation_080',
#  'BraTS20_Validation_009',
#  'BraTS20_Validation_104',
#  'BraTS20_Validation_086',
#  'BraTS20_Validation_013',
#  'BraTS20_Validation_048',
#  'BraTS20_Validation_039',
#  'BraTS20_Validation_083',
#  'BraTS20_Validation_023',
#  'BraTS20_Validation_107',
#  'survival_evaluation.csv',
#  'BraTS20_Validation_099',
#  'BraTS20_Validation_075',
#  'BraTS20_Validation_041',
#  'BraTS20_Validation_114',
#  'BraTS20_Validation_032',
#  'BraTS20_Validation_052',
#  'BraTS20_Validation_029',
#  'BraTS20_Validation_001',
#  'BraTS20_Validation_122',
#  'BraTS20_Validation_088',
#  'BraTS20_Validation_093',
#  'BraTS20_Validation_024',
#  'BraTS20_Validation_087',
#  'BraTS20_Validation_067',
#  'BraTS20_Validation_113',
#  'BraTS20_Validation_123',
#  'BraTS20_Validation_125',
#  'BraTS20_Validation_120',
#  'BraTS20_Validation_077']

# %%
print(len(os.listdir(TRAIN_DATASET_PATH)))
print(len(os.listdir(VALIDATION_DATASET_PATH)))
# Out:
# 123
# 127

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model = build_unet(input_layer, 'he_normal', 0.2)
model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing] )

# %%
""" Verilerin yüklenmesi"""

train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
        
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories)


train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
""" (İsteğe bağlı data generator) Verilerimizin boyutu çok büyük olduğundan dolayı biz bu verilerin hepsini Ram'e almak istemedik. Altarnatif çözüm olarak 
Stanford Üniversitesinin 2 Hocası tarafından geliştirilen Data Generatörü projemize dahil ettik."""


class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))


        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii')
            flair = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t1ce.nii')
            ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_seg.nii')
            seg = nib.load(data_path).get_fdata()

            for j in range(VOLUME_SLICES):
                X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT]

        # Generate masks
        y[y==4] = 3
        mask = tf.one_hot(y, 4)
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        return X/np.max(X), Y

training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
"""Veri setimizin dağılım grafiği"""

def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')

    plt.show()

showDataLayout()

# %%
""" modelin eğitim sırasında oluşan tüm değerleri tutar ve kaydeder.        egitim.log"""

csv_logger = CSVLogger('egitim.log', separator=',', append=False)

"""
During the training of the model, the code snippet creates two callbacks.

The first callback, CSVLogger, logs and saves all the values that are generated during the training process to a CSV file named 'egitim.log'. This can be used to analyze the training process later.

The second callback, ReduceLROnPlateau, modifies the learning rate of the model by a factor of 0.2 if there is no improvement in the validation loss for two consecutive epochs. This can speed up the learning process during training by changing the weight states related to the learning rate by 2 to 10 times faster than the normal training. This callback is called at the end of every epoch, and it tracks the validation loss as a parameter.

Both callbacks are passed to the fit method of the Keras model during training.
"""

callbacks = [
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=2, min_lr=0.000001, verbose=1),

        csv_logger
    ]

# %%
#model fit
K.clear_session()

history =  model.fit(training_generator,
                     epochs=20,
                     steps_per_epoch=len(train_ids),
                     callbacks= callbacks,
                     validation_data = valid_generator
                     )
model.save("u-net_part3.h5")
# Out:
# Epoch 1/20
# 2023-05-06 06:23:03.724105: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 83/83 [==============================] - 93s 891ms/step - loss: 0.2574 - accuracy: 0.9700 - mean_io_u_1: 0.4869 - dice_coef: 0.2461 - precision: 0.9659 - sensitivity: 0.9248 - specificity: 0.9939 - dice_coef_necrotic: 0.0497 - dice_coef_edema: 0.0627 - dice_coef_enhancing: 0.0167 - val_loss: 0.1092 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.6480 - val_dice_coef: 0.2661 - val_precision: 0.9789 - val_sensitivity: 0.9789 - val_specificity: 0.9930 - val_dice_coef_necrotic: 0.0843 - val_dice_coef_edema: 0.0726 - val_dice_coef_enhancing: 0.0101 - lr: 0.0010
# Epoch 2/20
# 83/83 [==============================] - 43s 518ms/step - loss: 0.0862 - accuracy: 0.9814 - mean_io_u_1: 0.6420 - dice_coef: 0.2662 - precision: 0.9813 - sensitivity: 0.9813 - specificity: 0.9938 - dice_coef_necrotic: 0.0748 - dice_coef_edema: 0.1021 - dice_coef_enhancing: 0.0220 - val_loss: 0.0872 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.6218 - val_dice_coef: 0.2771 - val_precision: 0.9788 - val_sensitivity: 0.9788 - val_specificity: 0.9930 - val_dice_coef_necrotic: 0.1195 - val_dice_coef_edema: 0.1359 - val_dice_coef_enhancing: 0.0397 - lr: 0.0010
# Epoch 3/20
# 83/83 [==============================] - 42s 508ms/step - loss: 0.0883 - accuracy: 0.9814 - mean_io_u_1: 0.6519 - dice_coef: 0.2674 - precision: 0.9813 - sensitivity: 0.9812 - specificity: 0.9938 - dice_coef_necrotic: 0.0763 - dice_coef_edema: 0.1063 - dice_coef_enhancing: 0.0260 - val_loss: 0.0908 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.6708 - val_dice_coef: 0.2652 - val_precision: 0.9790 - val_sensitivity: 0.9790 - val_specificity: 0.9930 - val_dice_coef_necrotic: 0.0409 - val_dice_coef_edema: 0.0731 - val_dice_coef_enhancing: 0.0111 - lr: 0.0010
# Epoch 4/20
# 83/83 [==============================] - 43s 511ms/step - loss: 0.0808 - accuracy: 0.9814 - mean_io_u_1: 0.6850 - dice_coef: 0.2694 - precision: 0.9813 - sensitivity: 0.9813 - specificity: 0.9938 - dice_coef_necrotic: 0.0799 - dice_coef_edema: 0.1134 - dice_coef_enhancing: 0.0273 - val_loss: 0.0869 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.7228 - val_dice_coef: 0.2696 - val_precision: 0.9789 - val_sensitivity: 0.9790 - val_specificity: 0.9930 - val_dice_coef_necrotic: 0.0509 - val_dice_coef_edema: 0.0831 - val_dice_coef_enhancing: 0.0294 - lr: 0.0010
# Epoch 5/20
# 83/83 [==============================] - 42s 508ms/step - loss: 0.0780 - accuracy: 0.9814 - mean_io_u_1: 0.6973 - dice_coef: 0.2733 - precision: 0.9814 - sensitivity: 0.9812 - specificity: 0.9938 - dice_coef_necrotic: 0.0869 - dice_coef_edema: 0.1264 - dice_coef_enhancing: 0.0418 - val_loss: 0.0982 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.8038 - val_dice_coef: 0.2646 - val_precision: 0.9790 - val_sensitivity: 0.9790 - val_specificity: 0.9930 - val_dice_coef_necrotic: 0.0436 - val_dice_coef_edema: 0.0529 - val_dice_coef_enhancing: 0.0057 - lr: 0.0010
# Epoch 6/20
# 83/83 [==============================] - 42s 505ms/step - loss: 0.0813 - accuracy: 0.9814 - mean_io_u_1: 0.7081 - dice_coef: 0.2730 - precision: 0.9815 - sensitivity: 0.9812 - specificity: 0.9939 - dice_coef_necrotic: 0.0940 - dice_coef_edema: 0.1282 - dice_coef_enhancing: 0.0353 - val_loss: 0.0860 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.6714 - val_dice_coef: 0.2735 - val_precision: 0.9793 - val_sensitivity: 0.9789 - val_specificity: 0.9931 - val_dice_coef_necrotic: 0.0723 - val_dice_coef_edema: 0.1087 - val_dice_coef_enhancing: 0.0256 - lr: 0.0010
# Epoch 7/20
# 83/83 [==============================] - 46s 549ms/step - loss: 0.0786 - accuracy: 0.9814 - mean_io_u_1: 0.7002 - dice_coef: 0.2744 - precision: 0.9818 - sensitivity: 0.9812 - specificity: 0.9939 - dice_coef_necrotic: 0.0969 - dice_coef_edema: 0.1300 - dice_coef_enhancing: 0.0358 - val_loss: 0.0855 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.6028 - val_dice_coef: 0.2831 - val_precision: 0.9788 - val_sensitivity: 0.9787 - val_specificity: 0.9930 - val_dice_coef_necrotic: 0.1223 - val_dice_coef_edema: 0.1715 - val_dice_coef_enhancing: 0.0929 - lr: 0.0010
# Epoch 8/20
# 83/83 [==============================] - 42s 503ms/step - loss: 0.0784 - accuracy: 0.9814 - mean_io_u_1: 0.6520 - dice_coef: 0.2764 - precision: 0.9822 - sensitivity: 0.9805 - specificity: 0.9941 - dice_coef_necrotic: 0.1106 - dice_coef_edema: 0.1269 - dice_coef_enhancing: 0.0490 - val_loss: 0.0800 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.6711 - val_dice_coef: 0.2818 - val_precision: 0.9788 - val_sensitivity: 0.9788 - val_specificity: 0.9930 - val_dice_coef_necrotic: 0.1028 - val_dice_coef_edema: 0.1560 - val_dice_coef_enhancing: 0.0744 - lr: 0.0010
# Epoch 9/20
# 83/83 [==============================] - 42s 505ms/step - loss: 0.0769 - accuracy: 0.9814 - mean_io_u_1: 0.6294 - dice_coef: 0.2795 - precision: 0.9828 - sensitivity: 0.9801 - specificity: 0.9943 - dice_coef_necrotic: 0.1140 - dice_coef_edema: 0.1404 - dice_coef_enhancing: 0.0524 - val_loss: 0.0797 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.4869 - val_dice_coef: 0.2791 - val_precision: 0.9791 - val_sensitivity: 0.9789 - val_specificity: 0.9930 - val_dice_coef_necrotic: 0.0851 - val_dice_coef_edema: 0.1459 - val_dice_coef_enhancing: 0.0330 - lr: 0.0010
# Epoch 10/20
# 83/83 [==============================] - 42s 506ms/step - loss: 0.0717 - accuracy: 0.9814 - mean_io_u_1: 0.6699 - dice_coef: 0.2879 - precision: 0.9834 - sensitivity: 0.9805 - specificity: 0.9945 - dice_coef_necrotic: 0.1339 - dice_coef_edema: 0.1656 - dice_coef_enhancing: 0.0701 - val_loss: 0.0820 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.7434 - val_dice_coef: 0.2848 - val_precision: 0.9796 - val_sensitivity: 0.9789 - val_specificity: 0.9932 - val_dice_coef_necrotic: 0.0997 - val_dice_coef_edema: 0.1092 - val_dice_coef_enhancing: 0.0356 - lr: 0.0010
# Epoch 11/20
# 83/83 [==============================] - 42s 510ms/step - loss: 0.0734 - accuracy: 0.9814 - mean_io_u_1: 0.6494 - dice_coef: 0.2900 - precision: 0.9842 - sensitivity: 0.9790 - specificity: 0.9947 - dice_coef_necrotic: 0.1379 - dice_coef_edema: 0.1708 - dice_coef_enhancing: 0.0782 - val_loss: 0.0780 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.4623 - val_dice_coef: 0.2886 - val_precision: 0.9794 - val_sensitivity: 0.9788 - val_specificity: 0.9932 - val_dice_coef_necrotic: 0.0991 - val_dice_coef_edema: 0.1476 - val_dice_coef_enhancing: 0.0835 - lr: 0.0010
# Epoch 12/20
# 83/83 [==============================] - 42s 508ms/step - loss: 0.0738 - accuracy: 0.9814 - mean_io_u_1: 0.4984 - dice_coef: 0.2848 - precision: 0.9829 - sensitivity: 0.9792 - specificity: 0.9943 - dice_coef_necrotic: 0.1329 - dice_coef_edema: 0.1519 - dice_coef_enhancing: 0.0614 - val_loss: 0.0768 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.6550 - val_dice_coef: 0.2940 - val_precision: 0.9791 - val_sensitivity: 0.9788 - val_specificity: 0.9931 - val_dice_coef_necrotic: 0.1236 - val_dice_coef_edema: 0.1753 - val_dice_coef_enhancing: 0.0505 - lr: 0.0010
# Epoch 13/20
# 83/83 [==============================] - 42s 509ms/step - loss: 0.0672 - accuracy: 0.9814 - mean_io_u_1: 0.4887 - dice_coef: 0.3025 - precision: 0.9849 - sensitivity: 0.9787 - specificity: 0.9949 - dice_coef_necrotic: 0.1690 - dice_coef_edema: 0.2123 - dice_coef_enhancing: 0.0864 - val_loss: 0.0699 - val_accuracy: 0.9791 - val_mean_io_u_1: 0.5423 - val_dice_coef: 0.3116 - val_precision: 0.9835 - val_sensitivity: 0.9746 - val_specificity: 0.9945 - val_dice_coef_necrotic: 0.1859 - val_dice_coef_edema: 0.2515 - val_dice_coef_enhancing: 0.1117 - lr: 0.0010
# Epoch 14/20
# 83/83 [==============================] - 42s 504ms/step - loss: 0.0667 - accuracy: 0.9814 - mean_io_u_1: 0.5005 - dice_coef: 0.3030 - precision: 0.9844 - sensitivity: 0.9794 - specificity: 0.9948 - dice_coef_necrotic: 0.1694 - dice_coef_edema: 0.2152 - dice_coef_enhancing: 0.0954 - val_loss: 0.0660 - val_accuracy: 0.9790 - val_mean_io_u_1: 0.4630 - val_dice_coef: 0.3126 - val_precision: 0.9801 - val_sensitivity: 0.9788 - val_specificity: 0.9934 - val_dice_coef_necrotic: 0.1650 - val_dice_coef_edema: 0.1989 - val_dice_coef_enhancing: 0.0990 - lr: 0.0010
# Epoch 15/20
# 83/83 [==============================] - 42s 509ms/step - loss: 0.0559 - accuracy: 0.9818 - mean_io_u_1: 0.4754 - dice_coef: 0.3287 - precision: 0.9880 - sensitivity: 0.9782 - specificity: 0.9959 - dice_coef_necrotic: 0.2237 - dice_coef_edema: 0.2792 - dice_coef_enhancing: 0.1284 - val_loss: 0.0552 - val_accuracy: 0.9808 - val_mean_io_u_1: 0.4857 - val_dice_coef: 0.3499 - val_precision: 0.9880 - val_sensitivity: 0.9771 - val_specificity: 0.9959 - val_dice_coef_necrotic: 0.2626 - val_dice_coef_edema: 0.3315 - val_dice_coef_enhancing: 0.1765 - lr: 0.0010
# Epoch 16/20
# 83/83 [==============================] - 43s 512ms/step - loss: 0.0503 - accuracy: 0.9827 - mean_io_u_1: 0.4925 - dice_coef: 0.3460 - precision: 0.9903 - sensitivity: 0.9785 - specificity: 0.9967 - dice_coef_necrotic: 0.2539 - dice_coef_edema: 0.3262 - dice_coef_enhancing: 0.1501 - val_loss: 0.0547 - val_accuracy: 0.9824 - val_mean_io_u_1: 0.4869 - val_dice_coef: 0.3647 - val_precision: 0.9932 - val_sensitivity: 0.9722 - val_specificity: 0.9975 - val_dice_coef_necrotic: 0.3117 - val_dice_coef_edema: 0.4131 - val_dice_coef_enhancing: 0.1865 - lr: 0.0010
# Epoch 17/20
# 83/83 [==============================] - 42s 505ms/step - loss: 0.0452 - accuracy: 0.9842 - mean_io_u_1: 0.4661 - dice_coef: 0.3679 - precision: 0.9925 - sensitivity: 0.9782 - specificity: 0.9974 - dice_coef_necrotic: 0.3024 - dice_coef_edema: 0.3980 - dice_coef_enhancing: 0.1562 - val_loss: 0.0476 - val_accuracy: 0.9836 - val_mean_io_u_1: 0.4892 - val_dice_coef: 0.3896 - val_precision: 0.9938 - val_sensitivity: 0.9748 - val_specificity: 0.9977 - val_dice_coef_necrotic: 0.3635 - val_dice_coef_edema: 0.4100 - val_dice_coef_enhancing: 0.2259 - lr: 0.0010
# Epoch 18/20
# 83/83 [==============================] - 42s 506ms/step - loss: 0.0578 - accuracy: 0.9826 - mean_io_u_1: 0.4568 - dice_coef: 0.3344 - precision: 0.9889 - sensitivity: 0.9784 - specificity: 0.9962 - dice_coef_necrotic: 0.2524 - dice_coef_edema: 0.2843 - dice_coef_enhancing: 0.1372 - val_loss: 0.0527 - val_accuracy: 0.9828 - val_mean_io_u_1: 0.4551 - val_dice_coef: 0.3676 - val_precision: 0.9923 - val_sensitivity: 0.9745 - val_specificity: 0.9973 - val_dice_coef_necrotic: 0.3444 - val_dice_coef_edema: 0.3668 - val_dice_coef_enhancing: 0.2068 - lr: 0.0010
# Epoch 19/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9843 - mean_io_u_1: 0.4575 - dice_coef: 0.3626 - precision: 0.9912 - sensitivity: 0.9785 - specificity: 0.9970 - dice_coef_necrotic: 0.3166 - dice_coef_edema: 0.3718 - dice_coef_enhancing: 0.1707
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 83/83 [==============================] - 42s 507ms/step - loss: 0.0494 - accuracy: 0.9843 - mean_io_u_1: 0.4575 - dice_coef: 0.3626 - precision: 0.9912 - sensitivity: 0.9785 - specificity: 0.9970 - dice_coef_necrotic: 0.3166 - dice_coef_edema: 0.3718 - dice_coef_enhancing: 0.1707 - val_loss: 0.0500 - val_accuracy: 0.9833 - val_mean_io_u_1: 0.3990 - val_dice_coef: 0.3725 - val_precision: 0.9892 - val_sensitivity: 0.9774 - val_specificity: 0.9963 - val_dice_coef_necrotic: 0.2555 - val_dice_coef_edema: 0.4237 - val_dice_coef_enhancing: 0.2421 - lr: 0.0010
# Epoch 20/20
# 83/83 [==============================] - 42s 505ms/step - loss: 0.0426 - accuracy: 0.9853 - mean_io_u_1: 0.4225 - dice_coef: 0.3790 - precision: 0.9927 - sensitivity: 0.9788 - specificity: 0.9974 - dice_coef_necrotic: 0.3296 - dice_coef_edema: 0.4036 - dice_coef_enhancing: 0.2054 - val_loss: 0.0438 - val_accuracy: 0.9848 - val_mean_io_u_1: 0.4236 - val_dice_coef: 0.4112 - val_precision: 0.9913 - val_sensitivity: 0.9783 - val_specificity: 0.9970 - val_dice_coef_necrotic: 0.3667 - val_dice_coef_edema: 0.4652 - val_dice_coef_enhancing: 0.2549 - lr: 2.0000e-04

# %%
#Modelin yüklenmesi
#Modelin tahmin aşamasında kullanması için eğitim sonrası değerleri tekrar yükledik.
model = keras.models.load_model('/kaggle/working/u-net_part3.h5', 
                                   custom_objects={ 'accuracy' : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef": dice_coef,
                                                   "precision": precision,
                                                   "sensitivity":sensitivity,
                                                   "specificity":specificity,
                                                   "dice_coef_necrotic": dice_coef_necrotic,
                                                   "dice_coef_edema": dice_coef_edema,
                                                   "dice_coef_enhancing": dice_coef_enhancing
                                                  }, compile=False)

#Eğitim sonrası bize grafikleri verdi 
history = pd.read_csv('/kaggle/working/egitim.log', sep=',', engine='python')

hist=history



acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,3,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()


plt.show()
