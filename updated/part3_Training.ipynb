# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps
import nilearn as nl
import nibabel as nib

# ml libs
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard




np.set_printoptions(precision=3, suppress=True)

# %%
"""
Label definition and required parameters
"""
SEGMENT_CLASSES = {
0 : 'No Tumor',
1 : 'Necrotic/Nuclear', #Tumor Nucleus
2 : 'Edema',#Edema Part
3 : 'Expanding Tumor' #Expanding Tumor Part
}

IMG_SIZE=64


VOLUME_SLICES = 100
VOLUME_START_AT = 22

# %%
# Verilerin ön incelenmesi ve görselleştirilmesi
TRAIN_DATASET_PATH = '/home/ioj24/Desktop/Multimodal Image Segmentation/Datasets/BraTS2020_TrainingData/part3_training'
VALIDATION_DATASET_PATH = '/home/ioj24/Desktop/Multimodal Image Segmentation/Datasets/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData'

# %%
"""Bu kod, böbrek ve beyin tümörlerinin segmentasyonu için Dice katsayısı, doğruluk, duyarlılık ve özgüllük gibi değerlerin hesaplanmasını sağlar.
dice_coef fonksiyonu, verilen gerçek ve tahmini etiketler arasında Dice katsayısını hesaplar ve döndürür. 
dice_coef_necrotic, dice_coef_edema ve dice_coef_enhancing fonksiyonları ise sırasıyla nekrotik, ödemli ve genişleyen tümör bölgeleri için 
Dice katsayısını hesaplar.precision fonksiyonu, verilen gerçek ve tahmini etiketler arasında doğruluk değerini hesaplar ve döndürür.
sensitivity fonksiyonu, verilen gerçek etiketler ve tahmini etiketler arasında duyarlılık değerini hesaplar ve döndürür.
specificity fonksiyonu ise verilen gerçek etiketler ve tahmini etiketler arasında özgüllük değerini hesaplar ve döndürür."""

def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
  
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss


def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,1])) + K.sum(K.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,2])) + K.sum(K.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,3])) + K.sum(K.square(y_pred[:,:,:,3])) + epsilon)



def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision


def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
import os
os.listdir(TRAIN_DATASET_PATH)
os.listdir(VALIDATION_DATASET_PATH)
# Out:
# ['BraTS20_Validation_010',
#  'BraTS20_Validation_121',
#  'BraTS20_Validation_105',
#  'BraTS20_Validation_097',
#  'BraTS20_Validation_100',
#  'BraTS20_Validation_019',
#  'BraTS20_Validation_008',
#  'BraTS20_Validation_022',
#  'BraTS20_Validation_112',
#  'BraTS20_Validation_088',
#  'BraTS20_Validation_036',
#  'BraTS20_Validation_061',
#  'BraTS20_Validation_007',
#  'BraTS20_Validation_040',
#  'BraTS20_Validation_079',
#  'BraTS20_Validation_065',
#  'BraTS20_Validation_066',
#  'BraTS20_Validation_115',
#  'BraTS20_Validation_110',
#  'BraTS20_Validation_090',
#  'BraTS20_Validation_084',
#  'BraTS20_Validation_018',
#  'BraTS20_Validation_124',
#  'BraTS20_Validation_032',
#  'BraTS20_Validation_120',
#  'BraTS20_Validation_074',
#  'BraTS20_Validation_029',
#  'BraTS20_Validation_012',
#  'BraTS20_Validation_101',
#  'BraTS20_Validation_005',
#  'BraTS20_Validation_116',
#  'BraTS20_Validation_067',
#  'BraTS20_Validation_070',
#  'BraTS20_Validation_081',
#  'BraTS20_Validation_086',
#  'BraTS20_Validation_089',
#  'BraTS20_Validation_049',
#  'BraTS20_Validation_056',
#  'BraTS20_Validation_087',
#  'BraTS20_Validation_030',
#  'BraTS20_Validation_027',
#  'survival_evaluation.csv',
#  'BraTS20_Validation_033',
#  'BraTS20_Validation_031',
#  'BraTS20_Validation_080',
#  'BraTS20_Validation_028',
#  'BraTS20_Validation_107',
#  'BraTS20_Validation_069',
#  'BraTS20_Validation_068',
#  'BraTS20_Validation_096',
#  'BraTS20_Validation_057',
#  'BraTS20_Validation_077',
#  'BraTS20_Validation_092',
#  'BraTS20_Validation_051',
#  'BraTS20_Validation_111',
#  'BraTS20_Validation_053',
#  'BraTS20_Validation_123',
#  'BraTS20_Validation_114',
#  'BraTS20_Validation_062',
#  'BraTS20_Validation_098',
#  'BraTS20_Validation_035',
#  'BraTS20_Validation_055',
#  'BraTS20_Validation_102',
#  'BraTS20_Validation_103',
#  'BraTS20_Validation_078',
#  'BraTS20_Validation_104',
#  'BraTS20_Validation_071',
#  'BraTS20_Validation_122',
#  'BraTS20_Validation_082',
#  'BraTS20_Validation_048',
#  'BraTS20_Validation_020',
#  'BraTS20_Validation_024',
#  'BraTS20_Validation_011',
#  'BraTS20_Validation_006',
#  'BraTS20_Validation_009',
#  'BraTS20_Validation_106',
#  'BraTS20_Validation_017',
#  'BraTS20_Validation_045',
#  'BraTS20_Validation_046',
#  'BraTS20_Validation_095',
#  'BraTS20_Validation_004',
#  'BraTS20_Validation_099',
#  'BraTS20_Validation_059',
#  'BraTS20_Validation_060',
#  'BraTS20_Validation_073',
#  'BraTS20_Validation_021',
#  'BraTS20_Validation_001',
#  'BraTS20_Validation_108',
#  'BraTS20_Validation_054',
#  'name_mapping_validation_data.csv',
#  'BraTS20_Validation_052',
#  'BraTS20_Validation_016',
#  'BraTS20_Validation_023',
#  'BraTS20_Validation_026',
#  'BraTS20_Validation_064',
#  'BraTS20_Validation_063',
#  'BraTS20_Validation_002',
#  'BraTS20_Validation_025',
#  'BraTS20_Validation_050',
#  'BraTS20_Validation_083',
#  'BraTS20_Validation_003',
#  'BraTS20_Validation_013',
#  'BraTS20_Validation_015',
#  'BraTS20_Validation_125',
#  'BraTS20_Validation_093',
#  'BraTS20_Validation_113',
#  'BraTS20_Validation_034',
#  'BraTS20_Validation_118',
#  'BraTS20_Validation_039',
#  'BraTS20_Validation_042',
#  'BraTS20_Validation_076',
#  'BraTS20_Validation_091',
#  'BraTS20_Validation_014',
#  'BraTS20_Validation_043',
#  'BraTS20_Validation_038',
#  'BraTS20_Validation_044',
#  'BraTS20_Validation_119',
#  'BraTS20_Validation_075',
#  'BraTS20_Validation_072',
#  'BraTS20_Validation_085',
#  'BraTS20_Validation_037',
#  'BraTS20_Validation_109',
#  'BraTS20_Validation_094',
#  'BraTS20_Validation_041',
#  'BraTS20_Validation_058',
#  'BraTS20_Validation_047',
#  'BraTS20_Validation_117']

# %%
print(len(os.listdir(TRAIN_DATASET_PATH)))
print(len(os.listdir(VALIDATION_DATASET_PATH)))
# Out:
# 125
# 127

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model = build_unet(input_layer, 'he_normal', 0.2)
model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing] )

# %%
""" Verilerin yüklenmesi"""

train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
        
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories)


train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
""" (İsteğe bağlı data generator) Verilerimizin boyutu çok büyük olduğundan dolayı biz bu verilerin hepsini Ram'e almak istemedik. Altarnatif çözüm olarak 
Stanford Üniversitesinin 2 Hocası tarafından geliştirilen Data Generatörü projemize dahil ettik."""


class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))


        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii')
            flair = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t1ce.nii')
            ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_seg.nii')
            seg = nib.load(data_path).get_fdata()

            for j in range(VOLUME_SLICES):
                X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
                X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

                y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT]

        # Generate masks
        y[y==4] = 3
        mask = tf.one_hot(y, 4)
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE))
        return X/np.max(X), Y

training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
"""Veri setimizin dağılım grafiği"""

def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')

    plt.show()

showDataLayout()
# Out:
# No handles with labels found to put in legend.

# %%
""" modelin eğitim sırasında oluşan tüm değerleri tutar ve kaydeder.        egitim.log"""

csv_logger = CSVLogger('egitim_part3.log', separator=',', append=False)

"""
During the training of the model, the code snippet creates two callbacks.

The first callback, CSVLogger, logs and saves all the values that are generated during the training process to a CSV file named 'egitim.log'. This can be used to analyze the training process later.

The second callback, ReduceLROnPlateau, modifies the learning rate of the model by a factor of 0.2 if there is no improvement in the validation loss for two consecutive epochs. This can speed up the learning process during training by changing the weight states related to the learning rate by 2 to 10 times faster than the normal training. This callback is called at the end of every epoch, and it tracks the validation loss as a parameter.

Both callbacks are passed to the fit method of the Keras model during training.
"""

callbacks = [
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=2, min_lr=0.000001, verbose=1),

        csv_logger
    ]

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 2)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   608         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 32)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)   0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 256)    295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)   0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 512)    1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 512)    2359808     ['conv2d_8[0][0]']
#
#  dropout (Dropout)              (None, 4, 4, 512)    0           ['conv2d_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 8, 8, 512)    0           ['dropout[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 256)    524544      ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 512)    0           ['conv2d_7[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    1179904     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 128)  131200      ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 128)  295040      ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 128)  147584      ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 128)  0          ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   32832       ['up_sampling2d_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 64)   73792       ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 64)   36928       ['conv2d_17[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 64)  0           ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 32)   8224        ['up_sampling2d_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_1[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 4)    132         ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 7,759,908
# Trainable params: 7,759,908
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#model fit
K.clear_session()

history =  model.fit(training_generator,
                     epochs=20,
                     steps_per_epoch=len(train_ids),
                     callbacks= callbacks,
                     validation_data = valid_generator
                     )
model.save("u-net_part3.h5")
# Out:
# Epoch 1/20
# 83/83 [==============================] - 92s 853ms/step - loss: 0.2781 - accuracy: 0.9570 - mean_io_u: 0.4531 - dice_coef: 0.2437 - precision: 0.9554 - sensitivity: 0.8969 - specificity: 0.9935 - dice_coef_necrotic: 0.0383 - dice_coef_edema: 0.0642 - dice_coef_enhancing: 0.0130 - val_loss: 0.0725 - val_accuracy: 0.9839 - val_mean_io_u: 0.4982 - val_dice_coef: 0.2649 - val_precision: 0.9839 - val_sensitivity: 0.9839 - val_specificity: 0.9946 - val_dice_coef_necrotic: 0.0699 - val_dice_coef_edema: 0.0933 - val_dice_coef_enhancing: 0.0200 - lr: 0.0010
# Epoch 2/20
# 83/83 [==============================] - 73s 882ms/step - loss: 0.0913 - accuracy: 0.9799 - mean_io_u: 0.5081 - dice_coef: 0.2673 - precision: 0.9798 - sensitivity: 0.9798 - specificity: 0.9933 - dice_coef_necrotic: 0.0731 - dice_coef_edema: 0.0995 - dice_coef_enhancing: 0.0268 - val_loss: 0.0742 - val_accuracy: 0.9839 - val_mean_io_u: 0.4525 - val_dice_coef: 0.2711 - val_precision: 0.9837 - val_sensitivity: 0.9837 - val_specificity: 0.9946 - val_dice_coef_necrotic: 0.1059 - val_dice_coef_edema: 0.1426 - val_dice_coef_enhancing: 0.0284 - lr: 0.0010
# Epoch 3/20
# 83/83 [==============================] - 73s 875ms/step - loss: 0.0893 - accuracy: 0.9799 - mean_io_u: 0.5563 - dice_coef: 0.2705 - precision: 0.9802 - sensitivity: 0.9787 - specificity: 0.9934 - dice_coef_necrotic: 0.0842 - dice_coef_edema: 0.1125 - dice_coef_enhancing: 0.0311 - val_loss: 0.0718 - val_accuracy: 0.9839 - val_mean_io_u: 0.4797 - val_dice_coef: 0.2732 - val_precision: 0.9837 - val_sensitivity: 0.9837 - val_specificity: 0.9946 - val_dice_coef_necrotic: 0.1048 - val_dice_coef_edema: 0.1531 - val_dice_coef_enhancing: 0.0202 - lr: 0.0010
# Epoch 4/20
# 83/83 [==============================] - 73s 882ms/step - loss: 0.0880 - accuracy: 0.9799 - mean_io_u: 0.5125 - dice_coef: 0.2720 - precision: 0.9798 - sensitivity: 0.9797 - specificity: 0.9933 - dice_coef_necrotic: 0.0841 - dice_coef_edema: 0.1195 - dice_coef_enhancing: 0.0315 - val_loss: 0.0699 - val_accuracy: 0.9839 - val_mean_io_u: 0.6477 - val_dice_coef: 0.2687 - val_precision: 0.9839 - val_sensitivity: 0.9839 - val_specificity: 0.9946 - val_dice_coef_necrotic: 0.0667 - val_dice_coef_edema: 0.0880 - val_dice_coef_enhancing: 0.0138 - lr: 0.0010
# Epoch 5/20
# 83/83 [==============================] - 72s 868ms/step - loss: 0.0862 - accuracy: 0.9799 - mean_io_u: 0.5043 - dice_coef: 0.2733 - precision: 0.9798 - sensitivity: 0.9797 - specificity: 0.9933 - dice_coef_necrotic: 0.0932 - dice_coef_edema: 0.1221 - dice_coef_enhancing: 0.0327 - val_loss: 0.0872 - val_accuracy: 0.9839 - val_mean_io_u: 0.4429 - val_dice_coef: 0.2757 - val_precision: 0.9838 - val_sensitivity: 0.9834 - val_specificity: 0.9947 - val_dice_coef_necrotic: 0.1533 - val_dice_coef_edema: 0.1912 - val_dice_coef_enhancing: 0.0416 - lr: 0.0010
# Epoch 6/20
# 83/83 [==============================] - 71s 851ms/step - loss: 0.0852 - accuracy: 0.9799 - mean_io_u: 0.5359 - dice_coef: 0.2747 - precision: 0.9801 - sensitivity: 0.9793 - specificity: 0.9934 - dice_coef_necrotic: 0.0945 - dice_coef_edema: 0.1281 - dice_coef_enhancing: 0.0361 - val_loss: 0.0691 - val_accuracy: 0.9839 - val_mean_io_u: 0.5137 - val_dice_coef: 0.2743 - val_precision: 0.9838 - val_sensitivity: 0.9838 - val_specificity: 0.9946 - val_dice_coef_necrotic: 0.1208 - val_dice_coef_edema: 0.1510 - val_dice_coef_enhancing: 0.0236 - lr: 0.0010
# Epoch 7/20
# 83/83 [==============================] - 71s 848ms/step - loss: 0.0825 - accuracy: 0.9799 - mean_io_u: 0.5111 - dice_coef: 0.2776 - precision: 0.9802 - sensitivity: 0.9793 - specificity: 0.9934 - dice_coef_necrotic: 0.1037 - dice_coef_edema: 0.1347 - dice_coef_enhancing: 0.0360 - val_loss: 0.0660 - val_accuracy: 0.9839 - val_mean_io_u: 0.4486 - val_dice_coef: 0.2746 - val_precision: 0.9838 - val_sensitivity: 0.9838 - val_specificity: 0.9946 - val_dice_coef_necrotic: 0.1198 - val_dice_coef_edema: 0.1383 - val_dice_coef_enhancing: 0.0175 - lr: 0.0010
# Epoch 8/20
# 83/83 [==============================] - 74s 885ms/step - loss: 0.0815 - accuracy: 0.9799 - mean_io_u: 0.5095 - dice_coef: 0.2791 - precision: 0.9802 - sensitivity: 0.9794 - specificity: 0.9934 - dice_coef_necrotic: 0.1125 - dice_coef_edema: 0.1341 - dice_coef_enhancing: 0.0387 - val_loss: 0.0779 - val_accuracy: 0.9839 - val_mean_io_u: 0.5339 - val_dice_coef: 0.2773 - val_precision: 0.9845 - val_sensitivity: 0.9834 - val_specificity: 0.9949 - val_dice_coef_necrotic: 0.1396 - val_dice_coef_edema: 0.1801 - val_dice_coef_enhancing: 0.0375 - lr: 0.0010
# Epoch 9/20
# 83/83 [==============================] - ETA: 0s - loss: 0.0792 - accuracy: 0.9799 - mean_io_u: 0.5708 - dice_coef: 0.2819 - precision: 0.9806 - sensitivity: 0.9796 - specificity: 0.9936 - dice_coef_necrotic: 0.1172 - dice_coef_edema: 0.1493 - dice_coef_enhancing: 0.0425
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 83/83 [==============================] - 74s 886ms/step - loss: 0.0792 - accuracy: 0.9799 - mean_io_u: 0.5708 - dice_coef: 0.2819 - precision: 0.9806 - sensitivity: 0.9796 - specificity: 0.9936 - dice_coef_necrotic: 0.1172 - dice_coef_edema: 0.1493 - dice_coef_enhancing: 0.0425 - val_loss: 0.0685 - val_accuracy: 0.9839 - val_mean_io_u: 0.5817 - val_dice_coef: 0.2818 - val_precision: 0.9859 - val_sensitivity: 0.9827 - val_specificity: 0.9953 - val_dice_coef_necrotic: 0.1636 - val_dice_coef_edema: 0.1585 - val_dice_coef_enhancing: 0.0334 - lr: 0.0010
# Epoch 10/20
# 83/83 [==============================] - 74s 892ms/step - loss: 0.0724 - accuracy: 0.9799 - mean_io_u: 0.5147 - dice_coef: 0.2909 - precision: 0.9817 - sensitivity: 0.9795 - specificity: 0.9939 - dice_coef_necrotic: 0.1618 - dice_coef_edema: 0.1604 - dice_coef_enhancing: 0.0536 - val_loss: 0.0613 - val_accuracy: 0.9839 - val_mean_io_u: 0.5226 - val_dice_coef: 0.2892 - val_precision: 0.9863 - val_sensitivity: 0.9833 - val_specificity: 0.9954 - val_dice_coef_necrotic: 0.1874 - val_dice_coef_edema: 0.1859 - val_dice_coef_enhancing: 0.0423 - lr: 2.0000e-04
# Epoch 11/20
# 83/83 [==============================] - 74s 891ms/step - loss: 0.0674 - accuracy: 0.9799 - mean_io_u: 0.5169 - dice_coef: 0.3002 - precision: 0.9826 - sensitivity: 0.9793 - specificity: 0.9942 - dice_coef_necrotic: 0.1710 - dice_coef_edema: 0.1874 - dice_coef_enhancing: 0.0686 - val_loss: 0.0577 - val_accuracy: 0.9839 - val_mean_io_u: 0.5262 - val_dice_coef: 0.2960 - val_precision: 0.9864 - val_sensitivity: 0.9831 - val_specificity: 0.9955 - val_dice_coef_necrotic: 0.1990 - val_dice_coef_edema: 0.1833 - val_dice_coef_enhancing: 0.0478 - lr: 2.0000e-04
# Epoch 12/20
# 83/83 [==============================] - 74s 884ms/step - loss: 0.0651 - accuracy: 0.9799 - mean_io_u: 0.5252 - dice_coef: 0.3078 - precision: 0.9846 - sensitivity: 0.9789 - specificity: 0.9949 - dice_coef_necrotic: 0.1876 - dice_coef_edema: 0.2076 - dice_coef_enhancing: 0.0861 - val_loss: 0.0559 - val_accuracy: 0.9839 - val_mean_io_u: 0.5344 - val_dice_coef: 0.3009 - val_precision: 0.9867 - val_sensitivity: 0.9832 - val_specificity: 0.9956 - val_dice_coef_necrotic: 0.2116 - val_dice_coef_edema: 0.1854 - val_dice_coef_enhancing: 0.0494 - lr: 2.0000e-04
# Epoch 13/20
# 83/83 [==============================] - 76s 906ms/step - loss: 0.0609 - accuracy: 0.9799 - mean_io_u: 0.5281 - dice_coef: 0.3175 - precision: 0.9861 - sensitivity: 0.9789 - specificity: 0.9954 - dice_coef_necrotic: 0.2087 - dice_coef_edema: 0.2192 - dice_coef_enhancing: 0.1004 - val_loss: 0.0720 - val_accuracy: 0.9841 - val_mean_io_u: 0.5241 - val_dice_coef: 0.2988 - val_precision: 0.9925 - val_sensitivity: 0.9699 - val_specificity: 0.9974 - val_dice_coef_necrotic: 0.2207 - val_dice_coef_edema: 0.2468 - val_dice_coef_enhancing: 0.0702 - lr: 2.0000e-04
# Epoch 14/20
# 83/83 [==============================] - 78s 936ms/step - loss: 0.0601 - accuracy: 0.9806 - mean_io_u: 0.5373 - dice_coef: 0.3254 - precision: 0.9874 - sensitivity: 0.9782 - specificity: 0.9958 - dice_coef_necrotic: 0.2270 - dice_coef_edema: 0.2499 - dice_coef_enhancing: 0.1243 - val_loss: 0.0502 - val_accuracy: 0.9854 - val_mean_io_u: 0.5268 - val_dice_coef: 0.3181 - val_precision: 0.9913 - val_sensitivity: 0.9808 - val_specificity: 0.9970 - val_dice_coef_necrotic: 0.2490 - val_dice_coef_edema: 0.2692 - val_dice_coef_enhancing: 0.0848 - lr: 2.0000e-04
# Epoch 15/20
# 83/83 [==============================] - 73s 870ms/step - loss: 0.0566 - accuracy: 0.9819 - mean_io_u: 0.5351 - dice_coef: 0.3402 - precision: 0.9893 - sensitivity: 0.9773 - specificity: 0.9963 - dice_coef_necrotic: 0.2363 - dice_coef_edema: 0.3064 - dice_coef_enhancing: 0.1423 - val_loss: 0.0665 - val_accuracy: 0.9826 - val_mean_io_u: 0.5294 - val_dice_coef: 0.3085 - val_precision: 0.9930 - val_sensitivity: 0.9689 - val_specificity: 0.9975 - val_dice_coef_necrotic: 0.2271 - val_dice_coef_edema: 0.2660 - val_dice_coef_enhancing: 0.0718 - lr: 2.0000e-04
# Epoch 16/20
# 83/83 [==============================] - 73s 881ms/step - loss: 0.0525 - accuracy: 0.9821 - mean_io_u: 0.5310 - dice_coef: 0.3465 - precision: 0.9898 - sensitivity: 0.9776 - specificity: 0.9965 - dice_coef_necrotic: 0.2606 - dice_coef_edema: 0.3193 - dice_coef_enhancing: 0.1493 - val_loss: 0.0476 - val_accuracy: 0.9854 - val_mean_io_u: 0.5965 - val_dice_coef: 0.3443 - val_precision: 0.9917 - val_sensitivity: 0.9800 - val_specificity: 0.9971 - val_dice_coef_necrotic: 0.2649 - val_dice_coef_edema: 0.3220 - val_dice_coef_enhancing: 0.1029 - lr: 2.0000e-04
# Epoch 17/20
# 83/83 [==============================] - 73s 879ms/step - loss: 0.0498 - accuracy: 0.9828 - mean_io_u: 0.5446 - dice_coef: 0.3616 - precision: 0.9908 - sensitivity: 0.9774 - specificity: 0.9968 - dice_coef_necrotic: 0.2794 - dice_coef_edema: 0.3507 - dice_coef_enhancing: 0.1660 - val_loss: 0.0449 - val_accuracy: 0.9856 - val_mean_io_u: 0.5344 - val_dice_coef: 0.3461 - val_precision: 0.9910 - val_sensitivity: 0.9822 - val_specificity: 0.9969 - val_dice_coef_necrotic: 0.3210 - val_dice_coef_edema: 0.2786 - val_dice_coef_enhancing: 0.0919 - lr: 2.0000e-04
# Epoch 18/20
# 83/83 [==============================] - 75s 895ms/step - loss: 0.0464 - accuracy: 0.9836 - mean_io_u: 0.5469 - dice_coef: 0.3732 - precision: 0.9924 - sensitivity: 0.9769 - specificity: 0.9973 - dice_coef_necrotic: 0.3281 - dice_coef_edema: 0.3706 - dice_coef_enhancing: 0.1834 - val_loss: 0.0413 - val_accuracy: 0.9858 - val_mean_io_u: 0.5813 - val_dice_coef: 0.3644 - val_precision: 0.9933 - val_sensitivity: 0.9798 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.3513 - val_dice_coef_edema: 0.3878 - val_dice_coef_enhancing: 0.1111 - lr: 2.0000e-04
# Epoch 19/20
# 83/83 [==============================] - 75s 904ms/step - loss: 0.0439 - accuracy: 0.9842 - mean_io_u: 0.5692 - dice_coef: 0.3882 - precision: 0.9928 - sensitivity: 0.9771 - specificity: 0.9974 - dice_coef_necrotic: 0.3661 - dice_coef_edema: 0.4179 - dice_coef_enhancing: 0.1938 - val_loss: 0.0410 - val_accuracy: 0.9869 - val_mean_io_u: 0.6149 - val_dice_coef: 0.3719 - val_precision: 0.9925 - val_sensitivity: 0.9820 - val_specificity: 0.9974 - val_dice_coef_necrotic: 0.3789 - val_dice_coef_edema: 0.3468 - val_dice_coef_enhancing: 0.1047 - lr: 2.0000e-04
# Epoch 20/20
# 83/83 [==============================] - 73s 881ms/step - loss: 0.0442 - accuracy: 0.9844 - mean_io_u: 0.5688 - dice_coef: 0.3888 - precision: 0.9923 - sensitivity: 0.9775 - specificity: 0.9973 - dice_coef_necrotic: 0.3656 - dice_coef_edema: 0.4078 - dice_coef_enhancing: 0.2080 - val_loss: 0.0545 - val_accuracy: 0.9817 - val_mean_io_u: 0.5500 - val_dice_coef: 0.3551 - val_precision: 0.9942 - val_sensitivity: 0.9723 - val_specificity: 0.9979 - val_dice_coef_necrotic: 0.3803 - val_dice_coef_edema: 0.3174 - val_dice_coef_enhancing: 0.1234 - lr: 2.0000e-04

# %%
#Modelin yüklenmesi
#Modelin tahmin aşamasında kullanması için eğitim sonrası değerleri tekrar yükledik.
model = keras.models.load_model('u-net_part3.h5', 
                                   custom_objects={ 'accuracy' : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef": dice_coef,
                                                   "precision": precision,
                                                   "sensitivity":sensitivity,
                                                   "specificity":specificity,
                                                   "dice_coef_necrotic": dice_coef_necrotic,
                                                   "dice_coef_edema": dice_coef_edema,
                                                   "dice_coef_enhancing": dice_coef_enhancing
                                                  }, compile=False)

#Eğitim sonrası bize grafikleri verdi 
history = pd.read_csv('egitim_part3.log', sep=',', engine='python')

hist=history



acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,3,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()


plt.show()
